# %% [markdown]
# This notebook is about customer churn prediction using Artificial Neural Network (ANN)

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv("/content/drive/MyDrive/Deeplearning, Keras and Tensorflow/WA_Fn-UseC_-Telco-Customer-Churn.csv")
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 748   6425-JWTDV    Male              0     Yes         No      48
# 4360  2675-OTVVJ    Male              1     Yes         No      31
# 517   6705-LXORM  Female              1     Yes         No       5
# 5260  2495-KZNFB  Female              0      No         No      33
# 4401  7576-JMYWV  Female              1     Yes        Yes      46
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 748           Yes            No              No  No internet service  ...
# 4360          Yes           Yes     Fiber optic                  Yes  ...
# 517           Yes            No     Fiber optic                   No  ...
# 5260          Yes           Yes     Fiber optic                  Yes  ...
# 4401          Yes           Yes     Fiber optic                  Yes  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# ...

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
#customer id is not useful in ML
df.drop("customerID", axis="columns", inplace=True)

# %%
df.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df.TotalCharges.values
# Out:
# array(['29.85', '1889.5', '108.15', ..., '346.45', '306.6', '6844.5'],
#       dtype=object)

# %%
# because the monthly charges are of string datatype it has to converted to float data type
pd.to_numeric(df.TotalCharges)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string " "
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-a1bec7fa1e92> in <cell line: 2>()
#       1 # because the monthly charges are of string datatype it has to converted to float data type
# ----> 2 pd.to_numeric(df.TotalCharges)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     183         coerce_numeric = errors not in ("ignore", "raise")
#     184         try:
# --> 185             values, _ = lib.maybe_convert_numeric(
#     186                 values, set(), coerce_numeric=coerce_numeric
# ...

# %%
# The above error is because the total charges field has <space>
# and that needs to be handled

# %%
# let's see which rows has space

# %%
# let's ignore the space error and convert the other fields

pd.to_numeric(df.TotalCharges, errors="coerce").isnull()
The above code will convert the string to numeric values
and prints whether the value is null or not
 null
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string " "
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-bb8b58ef5361> in <cell line: 3>()
#       1 # let's ignore the space error and convert the other fields
#       2
# ----> 3 pd.to_numeric(df.TotalCharges)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     183         coerce_numeric = errors not in ("ignore", "raise")
#     184         try:
# --> 185             values, _ = lib.maybe_convert_numeric(
#     186                 values, set(), coerce_numeric=coerce_numeric
#     187             )
#
# ...
